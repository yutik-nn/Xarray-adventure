# %%
# %matplotlib inline
import os                         
import xarray as xr 
import pandas as pd
import matplotlib                 
import matplotlib.pyplot as plt   
#plt.rcParams["figure.figsize"] = (9,6)  
import cartopy                  
import cartopy.crs as ccrs      
import plotly.express as px
import hvplot.xarray
import holoviews as hv
hv.extension('bokeh')
#hv.extension('plotly')
import numpy as np
import panel as pn
import panel.widgets as pnw
import ipywidgets as ipw
from sklearn import datasets, linear_model
from scipy import stats
from sklearn.metrics import mean_squared_error, r2_score
#from pycurrents.system import Bunch
import glob2
import hvplot.pandas  # noqa
import hvplot.xarray  # noqa
import cartopy.crs as ccrs
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
path = '/Users/ynorden/Research/code/coastal-sl/data/'
#eof_ds = xr.open_dataset(path+'eof_ds_correct.nc')
# SSH altimetry dataset
alt_ds = xr.open_dataset(path+ 'alt_filtered.nc')
# Principal components dataset (from previous notebook ideally)
pc_ds2 = xr.open_dataset(path+'pc_ds_jan_23.nc')
pc_ds = xr.open_dataset(path+'pc_ds.nc')
#pc_ds

# %%
import scipy.stats as ss
from scipy import linalg

def mlr(y, x, alpha=0.05):
    """
    Multiple linear regression.
    
        y: 2-D xarray dataarray
            (ntimes,) or (ntimes, nrealizations)
        x: 2-D array, model; (ntimes, nparams),numpy-array
    """
    print(y.shape)
    print(x.shape)
    y = y.T
    print(y.shape)
    y0 = np.reshape(y, (y.shape[0],y.shape[1]*y.shape[2]))
    print(y0.shape)
    ntimes, nparams = x.shape
    # if y0.shape[0] != ntimes:
    #     raise ValueError("Shape mismatch: x is %s, y is %s" %
    #                      x.shape, y0.shape)
    pinv = linalg.pinv(x)
    b = np.dot(pinv, y0)
    # 'pc' is a core dimension, move to the end
    b = np.reshape(b,(nparams,y.shape[1],y.shape[2])).T
    # pc_names = ['pc%s' % l for l in range(1,nparams+1)]
    # y.assign('beta':(('pc':pc_name,'latitude','longitude'),np.reshape(x.shape[1],y.latitude.data,y.longitude.data))
    
    return b

# %%
y4 = alt_ds.sla.data
x4=pc_ds.pc_n.data
#b2 = mlr(y4,x4)
#b2.shape

# %%
pc_ds.pc_n.dims
# Out:
# ('time', 'pc')

# %%
beta = xr.apply_ufunc(mlr,alt_ds.sla,pc_ds.pc_n,input_core_dims=[
    ['time'],  # for sla
    ['time', 'pc'], # for pc_00
],output_core_dims=[['pc']])
beta.sel(pc=1).plot(cmap='RdBu')
# Out:
# (121, 161, 9784)
# (9784, 31)
# (9784, 161, 121)
# (9784, 19481)

# %%
beta2 = xr.apply_ufunc(mlr,alt_ds.sla,pc_ds2.pc_00,input_core_dims=[
    ['time'],  # for sla
    ['time', 'pc'], # for pc_00
],output_core_dims=[['pc']])

# %%
beta2.sel(pc=1).hvplot(cmap='RdBu_r',clim=(-0.04,0.04),width=600,geo=True)
# Out:
# WARNING:param.GeoRasterPlot02025: Due to internal constraints, when aspect and width/height is set, the bokeh backend uses those values as frame_width/frame_height instead. This ensures the aspect is respected, but means that the plot might be slightly larger than anticipated. Set the frame_width/frame_height explicitly to suppress this warning.
# :Image   [longitude,latitude]   (value)

# %%
beta
# Out:
# <xarray.DataArray (latitude: 121, longitude: 161, pc: 33)>
# array([[[            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-1.55565171e-03, -1.46787093e-03,  1.14392779e-04, ...,
#           1.00796768e-02,  3.78554168e-02,  1.93613464e-01],
#         [-1.79789998e-03, -1.45611631e-03,  6.97921788e-04, ...,
#          -6.76516638e-03,  5.12003958e-02,  1.75313759e-01],
#         [-1.81474443e-03, -1.12472981e-03,  1.63163189e-03, ...,
#          -2.31993790e-02,  7.53724466e-02,  1.52630123e-01]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
# ...

# %%
#step by step index 3. 
y4 = alt_ds.sla.data
x4=pc_ds.pc_00.data
b0 = mlr(y4,x4)

# %%
b0 = np.reshape(b0,(33,121,161))
b0.T.shape
# Out:
# (161, 121, 33)

# %%
#step by step index 3. 
y3 = alt_ds.sla.data
x3=pc_ds.pc_00.data

y3 = np.reshape(y3, (y3.shape[0],y3.shape[1]*y3.shape[2]))
ntimes, nparams = x3.shape
print(y3.shape)
print(x3.shape)
# Out:
# (9784, 19481)
# (9784, 33)

# %%
pinv = linalg.pinv(x3)
b = np.dot(pinv, y3)
b = np.reshape(b,(33,121,161))
pc_names = ['pc%s' % l for l in range(1,34)]
b_ds = xr.Dataset({'beta':(('pc','lat','lon'),b),
                    },
                    {'pc':pc_names, 'lat': alt_ds.sla.latitude.data,'lon':alt_ds.sla.longitude.data},
                   )

# %%
b_ds.beta.sel(pc='pc1').plot()

# %%
y1 = alt_ds.sla.data
x1=pc_ds.pc_00.data
y1 = np.reshape(y1, (y1.shape[0],y1.shape[1]*y1.shape[2]))
y1
# Out:
# array([[    nan,     nan,     nan, ..., -0.0218, -0.0216, -0.0226],
#        [    nan,     nan,     nan, ..., -0.0146, -0.0153, -0.0174],
#        [    nan,     nan,     nan, ..., -0.0096, -0.0104, -0.0115],
#        ...,
#        [    nan,     nan,     nan, ...,  0.1735,  0.187 ,  0.1991],
#        [    nan,     nan,     nan, ...,  0.1713,  0.1824,  0.1916],
#        [    nan,     nan,     nan, ...,  0.164 ,  0.1735,  0.1797]])

# %%
new_b = mlr(y1,x1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 new_b = mlr(y1,x1)
#
# Cell In[20], line 12, in mlr(y, x, alpha)
#       4 def mlr(y, x, alpha=0.05):
#       5     """
#       6     Multiple linear regression.
#       7
#    (...)
#      10         x: 2-D array, model; (ntimes, nparams),numpy-array
#      11     """
# ---> 12     y = np.reshape(y, (y.shape[0],y.shape[1]*y.shape[2]))
#      13     ntimes, nparams = x.shape
#      14     # if y0.shape[0] != ntimes:
#      15     #     raise ValueError("Shape mismatch: x is %s, y is %s" %
#      16     #                      x.shape, y0.shape)
#
# IndexError: tuple index out of range

# %%
x1.shape
# Out:
# (9784, 33)

# %%
pc_ds.pc_00.shape
# Out:
# (9784, 33)

# %%
mlr1 = xr.apply_ufunc(mlr,alt_ds.sla,pc_ds.pc_00,output_core_dims=['mode'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mlr1 = xr.apply_ufunc(mlr,alt_ds.sla,pc_ds.pc_00,output_core_dims=['mode'])
#
# File ~/mambaforge/envs/siparcs/lib/python3.11/site-packages/xarray/core/computation.py:1197, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, *args)
#    1195 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1196 elif any(isinstance(a, DataArray) for a in args):
# -> 1197     return apply_dataarray_vfunc(
#    1198         variables_vfunc,
#    1199         *args,
#    1200         signature=signature,
#    1201         join=join,
#    1202         exclude_dims=exclude_dims,
#    1203         keep_attrs=keep_attrs,
#    1204     )
# ...

# %%
pc_ds.pc_00.shape
# Out:
# (9784, 33)
